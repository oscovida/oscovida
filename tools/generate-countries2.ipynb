# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import datetime
import json
import os
import shutil
import sys
from multiprocessing import Pool, cpu_count

import ipynb_py_convert
import nbformat
import numpy as np
from nbconvert import HTMLExporter
from nbconvert.preprocessors import ExecutePreprocessor
from nbconvert.writers import FilesWriter

from itertools import compress

# %%
from report_generators.reporters import CountryReport, GermanyReport, USAReport

# %%
debug = True

# %%
#  Set to false if you do not want multiprocessing enabled
cores = 'auto'

if cores == 'auto':
    cores = max(1, cpu_count())
    # try at most 4 to reduce probability of error message like
    # the one shown at https://github.com/jupyter/jupyter_client/issues/541
    cores = min(cores, 4)


if cores:
    print(f'Using {cores} processes')
    
wwwroot = "wwwroot"
# Out:
# Using 4 processes

# %%
# %config InlineBackend.figure_formats = ['svg']

from coronavirus import *
from coronavirus import MetadataRegion

pd.set_option('display.float_format', '{:.2f}'.format)  #  Disable pandas scientific notation

# %% [markdown]
# Cleaning of cache and copying files has moved to
#
# - `generate-webpage-clean-setup.py` and
# - `generate-webpage-clean-setup.sh`

# %%
TITLE_PREFIX = "Tracking plots: "

# %% [markdown]
# ### Download Datasets

# %%
d, c = fetch_deaths(), fetch_cases()

countries = d.index
countries2 = c.index
assert (countries2 == countries).all()

# %%
data_US_cases = fetch_cases_US()
data_US_deaths = fetch_deaths_US()

# %%
# also fetch data from Germany, so it is available later from the cache
germany = fetch_data_germany()

# %% [markdown]
# ### Generic Functions

# %%
def does_wwwroot_exist(wwwroot):
    if not os.path.exists(wwwroot):
        msg = "To put the html into github repo for webhosting, run "
        msg += '"git clone git@github.com:oscovida/oscovida.github.io.git wwwroot" or similar'
        # os.mkdir(wwwroot)
        raise ValueError(f"directory {wwwroot} missing.")

# %% [markdown]
# ## Index Page Generation

# %%
def create_markdown_index_list(category):
    """Assemble a markdown table like this:
    
    | Country/Region                       | Total cases   | Total deaths   |
    |:-------------------------------------|:--------------|:---------------|
    | [Afghanistan](html/Afghanistan.html) | 1,351         | 43             |
    | [Albania](html/Albania.html)         | 678           | 27             |
    | [Algeria](html/Algeria.html)         | 3,127         | 415            |
    | [Andorra](html/Andorra.html)         | 731           | 40             |
    
    and return as string.
    """
    
    known_categories = ["world", "Germany", "US"]
               
    # gather data
    regions_all = MetadataRegion.get_all_as_dataframe()
    if category in known_categories:
        # select those we are interested in
        regions = regions_all[regions_all['category'] == category]
    elif category in ["all-regions"]:
        regions = regions_all
    else:
        
        raise NotImplementedError(f"category {category} is unknown."+
                                  f" Known values are {known_categories + ['all-regions']}")
    
    # change index to contain URLs and one-line summary in markdown syntax
    def compose_md_url(x):
        one_line_summary, html = x
        if isinstance(html, str):
            return "[" + one_line_summary + "](" + os.path.join('html', html) +")"
        elif repr(html) == 'nan':   # if html was not produced, then variable html is np.nan
            print(f"Missing html for {one_line_summary} - will not add link to html: \n{x}")
            return one_line_summary
        else:
            raise NotImplementedError("Don't know how to proceed: ", one_line_summary, html, x)

    new_index = regions[['one-line-summary', 'html-file']].apply(compose_md_url, axis=1)
    regions2 = regions.set_index(new_index)
    regions2.index.name = "Location"
    
    # select columns
    regions3 = regions2[['max-cases', 'max-deaths', 'cases-last-week']]
    regions4 = regions3.applymap(lambda v: '{:,}'.format(v))  # Thousands comma separator
    
    # rename columns
    rename_dict = {'max-cases' : 'Total cases', 
                   'max-deaths' : 'Total deaths',
                   'cases-last-week' : 'New cases last week'}
    regions5 = regions4.rename(columns=rename_dict)

    return regions5.to_markdown()

# %%
def create_markdown_index_page(md_content, title, pelican_file_path, 
                               save_as, wwwroot, slug=None):
    """Create pelican markdown file, like this:
    
    title: Germany
    tags: Data, Plots, Germany
    save-as: germany
    date: 2020-04-11 08:00
    """

    if slug is None:
        slug = save_as
    
    with open(os.path.join(pelican_file_path), "tw") as f:
        f.write(f"title: {title}\n")
        # f.write(f"category: Data\n")  - have stopped using categories (22 April 2020)
        f.write(f"tags: Data, Plots, {title}\n")
        f.write(f"save-as: {save_as}\n")
        f.write(f"slug: {slug}\n")
        date_time = datetime.datetime.now().strftime("%Y/%m/%d %H:%M")
        f.write(f"date: {date_time}\n")
        f.write("\n")
        f.write("\n")
        f.write(md_content)
        f.write("\n")

# %%
def create_index_page(sections, rootname, wwwroot):
    """Sections is dictionary: key is title, value is markdown text"""
    md_file = rootname + ".md"
    
    with open(os.path.join(wwwroot, md_file), "tw") as f:
        for section in sections:
            f.write(f"# {section}\n\n")
            f.write(sections[section])
    print(f"Written overview to {md_file}.")
    html_file = rootname + ".html"
    subprocess.check_call(f"pandoc -t html -o {os.path.join(wwwroot, html_file)} " +
                          f"{os.path.join(wwwroot, md_file)}", shell=True)
    return html_file

# %% [markdown]
# ## Abstract Report Class

# %% [markdown]
# ### Serial and Parallel Report Functions

# %%
def create_html_reports_serial(Reporter, regions, wwwroot, expiry_hours=2, force=False):
    start_time = time.time()
    does_wwwroot_exist(wwwroot)
    skipped = 0

    for i, region in enumerate(regions):
        report = Reporter(region, wwwroot=wwwroot)
        if report.metadata.last_updated_hours_ago() < expiry_hours and not force:
            print(f"Skipping {report.title} - was updated "
                  f"{report.metadata.last_updated_hours_ago():.1f} hours ago")
            skipped += 1
            continue

        report.init_metadata()
    
        try:
            print(f"Processing {i+1}/{len(regions)} [{time.time()-start_time:4.0f}s]")
            report.generate()
        except Exception as e:
            print(f"Error for {report.title}", end='')
            print(e)
            raise e

        sys.stdout.flush()
        
    print(f"Created {len(regions)-skipped} (skipped {skipped}) notebooks and html versions in " + \
          f"{time.time()-start_time} seconds")
    
    sys.stdout.flush()

# %%
def create_html_report_parallel(Reporter, regions, wwwroot, pool, expiry_hours=2, force=False):
    processes = pool._processes
    padding = processes - (len(regions) % processes)
    regions = regions + ([None] * padding)
    per_process = int(len(regions)/processes)
    #  Weird way to create an evenly distributed list
    regions_per_process = [[] for p in range(processes)]
    [regions_per_process[p].append(r) for p, r in list(zip(list(range(processes))*per_process, regions))]
    regions_per_process = [list(filter(None.__ne__, process)) for process in regions_per_process]
    
    print(f"Using {processes} processes with tasks:")
    for n in range(pool._processes):
        if len(regions_per_process[n]) > 5:
            print(f"\t{n}: {regions_per_process[4]}")
        else:
            print(f"\t{n}: {regions_per_process[n]}")
    print("")
    sys.stdout.flush()
    
    tasks = ((Reporter, RPP, wwwroot, expiry_hours, force) for RPP in regions_per_process)
    
    res = pool.starmap(create_html_reports_serial, tasks)

# %%
def create_html_reports(*, Reporter, regions, wwwroot, cores=None, expiry_hours=2, force=False):
    if cores:
        with Pool(cores) as pool:
            create_html_report_parallel(Reporter, regions, wwwroot, pool, force=force)
    else:
        create_html_reports_serial(Reporter, regions, wwwroot, force=force)

# %% [markdown]
# ## Country Report Generation

# %%
def get_country_list():
    d, c = fetch_deaths(), fetch_cases()

    countries = d.index
    countries2 = c.index
    assert (countries2 == countries).all()
    
    # Here we should identify regions in countries, and process those.
    # Instead, as a quick hack to get started, we'll just take one country
    # and the current "get_country" method will sum over all regions of one country if only 
    # the country name is given.
    
    return sorted(countries.drop_duplicates())

# %%
countries = get_country_list()

if debug:
    countries = countries[0:8]
    cores=4

# %%
create_html_reports(
    Reporter=CountryReport, regions=countries,
    wwwroot=wwwroot, cores=cores, force=True
)
# Out:
# Using 4 processes with tasks:
# 	0: ['Afghanistan', 'Angola', 'Australia', 'Bahrain', 'Belgium', 'Bolivia', 'Brunei', 'Burundi', 'Canada', 'China', 'Congo (Kinshasa)', 'Cuba', 'Diamond Princess', 'Ecuador', 'Eritrea', 'Fiji', 'Gambia', 'Greece', 'Guinea-Bissau', 'Honduras', 'Indonesia', 'Israel', 'Jordan', 'Kosovo', 'Latvia', 'Libya', 'MS Zaandam', 'Maldives', 'Mauritius', 'Mongolia', 'Namibia', 'Nicaragua', 'Norway', 'Papua New Guinea', 'Poland', 'Russia', 'Saint Vincent and the Grenadines', 'Senegal', 'Singapore', 'South Africa', 'Sudan', 'Syria', 'Thailand', 'Tunisia', 'Ukraine', 'Uzbekistan', 'Western Sahara']
# 	1: ['Albania', 'Antigua and Barbuda', 'Austria', 'Bangladesh', 'Belize', 'Bosnia and Herzegovina', 'Bulgaria', 'Cabo Verde', 'Central African Republic', 'Colombia', 'Costa Rica', 'Cyprus', 'Djibouti', 'Egypt', 'Estonia', 'Finland', 'Georgia', 'Grenada', 'Guyana', 'Hungary', 'Iran', 'Italy', 'Kazakhstan', 'Kuwait', 'Lebanon', 'Liechtenstein', 'Madagascar', 'Mali', 'Mexico', 'Montenegro', 'Nepal', 'Niger', 'Oman', 'Paraguay', 'Portugal', 'Rwanda', 'San Marino', 'Serbia', 'Slovakia', 'South Sudan', 'Suriname', 'Taiwan*', 'Timor-Leste', 'Turkey', 'United Arab Emirates', 'Venezuela', 'Yemen']
# 	2: ['Algeria', 'Argentina', 'Azerbaijan', 'Barbados', 'Benin', 'Botswana', 'Burkina Faso', 'Cambodia', 'Chad', 'Comoros', "Cote d'Ivoire", 'Czechia', 'Dominica', 'El Salvador', 'Eswatini', 'France', 'Germany', 'Guatemala', 'Haiti', 'Iceland', 'Iraq', 'Jamaica', 'Kenya', 'Kyrgyzstan', 'Lesotho', 'Lithuania', 'Malawi', 'Malta', 'Moldova', 'Morocco', 'Netherlands', 'Nigeria', 'Pakistan', 'Peru', 'Qatar', 'Saint Kitts and Nevis', 'Sao Tome and Principe', 'Seychelles', 'Slovenia', 'Spain', 'Sweden', 'Tajikistan', 'Togo', 'US', 'United Kingdom', 'Vietnam', 'Zambia']
# 	3: ['Andorra', 'Armenia', 'Bahamas', 'Belarus', 'Bhutan', 'Brazil', 'Burma', 'Cameroon', 'Chile', 'Congo (Brazzaville)', 'Croatia', 'Denmark', 'Dominican Republic', 'Equatorial Guinea', 'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Holy See', 'India', 'Ireland', 'Japan', 'Korea, South', 'Laos', 'Liberia', 'Luxembourg', 'Malaysia', 'Mauritania', 'Monaco', 'Mozambique', 'New Zealand', 'North Macedonia', 'Panama', 'Philippines', 'Romania', 'Saint Lucia', 'Saudi Arabia', 'Sierra Leone', 'Somalia', 'Sri Lanka', 'Switzerland', 'Tanzania', 'Trinidad and Tobago', 'Uganda', 'Uruguay', 'West Bank and Gaza', 'Zimbabwe']
#
# Processing 1/47 [   0s]
# Processing 1/47 [   0s]
# wwwroot/ipynb/Algeria.ipynbwwwroot/ipynb/Albania.ipynb
#
# Written file to Algeria.ipynbWritten file to Albania.ipynb
#
# Processing 1/47 [   0s]Processing 1/47 [   0s]
#
# wwwroot/ipynb/Andorra.ipynbwwwroot/ipynb/Afghanistan.ipynb
#
# Written file to Afghanistan.ipynbWritten file to Andorra.ipynb
#
# Written file to wwwroot/html/Algeria.html
# Processing 2/47 [   4s]
# Written file to wwwroot/html/Afghanistan.html
# wwwroot/ipynb/Argentina.ipynb
# Written file to Argentina.ipynb
# Processing 2/47 [   4s]
# wwwroot/ipynb/Angola.ipynb
# Written file to Angola.ipynb
# Written file to wwwroot/html/Albania.html
# Processing 2/47 [   4s]
# wwwroot/ipynb/Antigua-and-Barbuda.ipynb
# Written file to Antigua-and-Barbuda.ipynb
# Written file to wwwroot/html/Andorra.html
# Processing 2/47 [   4s]
# wwwroot/ipynb/Armenia.ipynb
# Written file to Armenia.ipynb
# Written file to wwwroot/html/Armenia.html
# Processing 3/47 [   8s]
# wwwroot/ipynb/Bahamas.ipynb
# Written file to Bahamas.ipynb
# Written file to wwwroot/html/Antigua-and-Barbuda.html
# Processing 3/47 [   8s]
# wwwroot/ipynb/Austria.ipynb
# Written file to wwwroot/html/Angola.htmlWritten file to Austria.ipynb
#
# Written file to wwwroot/html/Argentina.html
# Processing 3/47 [   8s]
# wwwroot/ipynb/Australia.ipynb
# Written file to Australia.ipynbProcessing 3/47 [   8s]
#
# wwwroot/ipynb/Azerbaijan.ipynb
# Written file to Azerbaijan.ipynb
# Written file to wwwroot/html/Austria.html
# Written file to wwwroot/html/Azerbaijan.html
# Processing 4/47 [  12s]
# wwwroot/ipynb/Bangladesh.ipynb
# Written file to Bangladesh.ipynb
# Processing 4/47 [  12s]
# wwwroot/ipynb/Barbados.ipynb
# Written file to Barbados.ipynb
# Written file to wwwroot/html/Australia.html
# Processing 4/47 [  12s]
# wwwroot/ipynb/Bahrain.ipynb
# Written file to Bahrain.ipynb
# Written file to wwwroot/html/Bahamas.html
# Processing 4/47 [  12s]
# wwwroot/ipynb/Belarus.ipynb
# Written file to Belarus.ipynb
# Written file to wwwroot/html/Bangladesh.html
# Processing 5/47 [  15s]
# wwwroot/ipynb/Belize.ipynb
# Written file to Belize.ipynb
# Written file to wwwroot/html/Bahrain.html
# Written file to wwwroot/html/Belarus.html
# Processing 5/47 [  15s]
# wwwroot/ipynb/Belgium.ipynb
# Written file to Belgium.ipynb
# Processing 5/47 [  15s]
# wwwroot/ipynb/Bhutan.ipynb
# Written file to Bhutan.ipynb
# Written file to wwwroot/html/Barbados.html
# Processing 5/47 [  15s]
# wwwroot/ipynb/Benin.ipynb
# Written file to Benin.ipynb
# Written file to wwwroot/html/Belgium.html
# Written file to wwwroot/html/Belize.html
# Processing 6/47 [  19s]
# wwwroot/ipynb/Bolivia.ipynb
# Written file to Bolivia.ipynb
# Processing 6/47 [  19s]
# wwwroot/ipynb/Bosnia-and-Herzegovina.ipynb
# Written file to Bosnia-and-Herzegovina.ipynb
# Written file to wwwroot/html/Bhutan.html
# Written file to wwwroot/html/Benin.html
# Processing 6/47 [  19s]
# wwwroot/ipynb/Brazil.ipynb
# Written file to Brazil.ipynb
# Processing 6/47 [  19s]
# wwwroot/ipynb/Botswana.ipynb
# Written file to Botswana.ipynb
# Written file to wwwroot/html/Bolivia.html
# Processing 7/47 [  23s]
# wwwroot/ipynb/Brunei.ipynb
# Written file to Brunei.ipynb
# Written file to wwwroot/html/Brazil.html
# Processing 7/47 [  23s]
# wwwroot/ipynb/Burma.ipynb
# Written file to Burma.ipynb
# Written file to wwwroot/html/Botswana.html
# Processing 7/47 [  23s]
# wwwroot/ipynb/Burkina-Faso.ipynb
# Written file to Burkina-Faso.ipynb
# Written file to wwwroot/html/Bosnia-and-Herzegovina.html
# Processing 7/47 [  23s]
# wwwroot/ipynb/Bulgaria.ipynb
# Written file to Bulgaria.ipynb
# Written file to wwwroot/html/Brunei.html
# Processing 8/47 [  27s]
# wwwroot/ipynb/Burundi.ipynb
# Written file to Burundi.ipynb
# Written file to wwwroot/html/Burkina-Faso.html
# Processing 8/47 [  27s]
# wwwroot/ipynb/Cambodia.ipynb
# Written file to Cambodia.ipynb
# Written file to wwwroot/html/Burma.html
# Processing 8/47 [  27s]
# wwwroot/ipynb/Cameroon.ipynb
# Written file to Cameroon.ipynb
# Written file to wwwroot/html/Bulgaria.html
# Processing 8/47 [  27s]
# wwwroot/ipynb/Cabo-Verde.ipynb
# Written file to Cabo-Verde.ipynb
# Written file to wwwroot/html/Burundi.html
# Processing 9/47 [  31s]
# wwwroot/ipynb/Canada.ipynb
# Written file to Canada.ipynb
# Written file to wwwroot/html/Cameroon.html
# Processing 9/47 [  31s]
# wwwroot/ipynb/Chile.ipynb
# Written file to wwwroot/html/Cambodia.htmlWritten file to Chile.ipynb
#
# Processing 9/47 [  31s]
# wwwroot/ipynb/Chad.ipynb
# Written file to Chad.ipynb
# Written file to wwwroot/html/Cabo-Verde.html
# Processing 9/47 [  31s]
# wwwroot/ipynb/Central-African-Republic.ipynb
# Written file to Central-African-Republic.ipynb
# Written file to wwwroot/html/Canada.html
# Processing 10/47 [  34s]
# wwwroot/ipynb/China.ipynb
# Written file to China.ipynb
# Written file to wwwroot/html/Chile.html
# Processing 10/47 [  35s]
# wwwroot/ipynb/Congo-(Brazzaville).ipynb
# Written file to Congo-(Brazzaville).ipynb
# Written file to wwwroot/html/Chad.html
# Processing 10/47 [  35s]
# wwwroot/ipynb/Comoros.ipynb
# Written file to Comoros.ipynb
# Written file to wwwroot/html/Central-African-Republic.html
# Processing 10/47 [  35s]
# wwwroot/ipynb/Colombia.ipynb
# Written file to Colombia.ipynb
# Written file to wwwroot/html/China.html
# Processing 11/47 [  38s]
# wwwroot/ipynb/Congo-(Kinshasa).ipynb
# Written file to Congo-(Kinshasa).ipynb
# Written file to wwwroot/html/Comoros.html
# Processing 11/47 [  39s]
# wwwroot/ipynb/Cote-d'Ivoire.ipynb
# Written file to Cote-d'Ivoire.ipynb
# Written file to wwwroot/html/Congo-(Brazzaville).html
# Processing 11/47 [  39s]
# wwwroot/ipynb/Croatia.ipynb
# Written file to Croatia.ipynb
# Written file to wwwroot/html/Colombia.html
# Processing 11/47 [  39s]
# wwwroot/ipynb/Costa-Rica.ipynb
# Written file to Costa-Rica.ipynb
# Written file to wwwroot/html/Congo-(Kinshasa).html
# Processing 12/47 [  42s]
# wwwroot/ipynb/Cuba.ipynb
# Written file to Cuba.ipynb
# Written file to wwwroot/html/Cote-d'Ivoire.html
# Processing 12/47 [  43s]
# wwwroot/ipynb/Czechia.ipynb
# Written file to Czechia.ipynb
# Written file to wwwroot/html/Costa-Rica.html
# Written file to wwwroot/html/Croatia.html
# Processing 12/47 [  43s]
# wwwroot/ipynb/Cyprus.ipynb
# Written file to Cyprus.ipynb
# Processing 12/47 [  43s]
# wwwroot/ipynb/Denmark.ipynb
# Written file to Denmark.ipynb
# Written file to wwwroot/html/Cuba.html
# Processing 13/47 [  46s]
# wwwroot/ipynb/Diamond-Princess.ipynb
# Written file to Diamond-Princess.ipynb
# Written file to wwwroot/html/Czechia.html
# Processing 13/47 [  46s]
# wwwroot/ipynb/Dominica.ipynb
# Written file to Dominica.ipynb
# Written file to wwwroot/html/Denmark.html
# Processing 13/47 [  47s]
# wwwroot/ipynb/Dominican-Republic.ipynb
# Written file to Dominican-Republic.ipynb
# Written file to wwwroot/html/Cyprus.html
# Processing 13/47 [  47s]
# wwwroot/ipynb/Djibouti.ipynb
# Written file to Djibouti.ipynb
# Written file to wwwroot/html/Diamond-Princess.html
# Processing 14/47 [  50s]
# wwwroot/ipynb/Ecuador.ipynb
# Written file to Ecuador.ipynb
# Written file to wwwroot/html/Dominica.html
# Processing 14/47 [  50s]
# wwwroot/ipynb/El-Salvador.ipynb
# Written file to El-Salvador.ipynb
# Written file to wwwroot/html/Dominican-Republic.html
# Processing 14/47 [  50s]
# wwwroot/ipynb/Equatorial-Guinea.ipynb
# Written file to Equatorial-Guinea.ipynb
# Written file to wwwroot/html/Djibouti.html
# Processing 14/47 [  51s]
# wwwroot/ipynb/Egypt.ipynb
# Written file to Egypt.ipynb
# Written file to wwwroot/html/Ecuador.html
# Written file to wwwroot/html/El-Salvador.html
# Processing 15/47 [  54s]
# Processing 15/47 [  54s]wwwroot/ipynb/Eswatini.ipynb
#
# wwwroot/ipynb/Eritrea.ipynb
# Written file to Eswatini.ipynb
# Written file to Eritrea.ipynb
# Written file to wwwroot/html/Egypt.html
# Processing 15/47 [  54s]
# wwwroot/ipynb/Estonia.ipynb
# Written file to Estonia.ipynb
# Written file to wwwroot/html/Equatorial-Guinea.html
# Processing 15/47 [  54s]
# wwwroot/ipynb/Ethiopia.ipynb
# Written file to Ethiopia.ipynb
# Written file to wwwroot/html/Eswatini.html
# Written file to wwwroot/html/Eritrea.html
# Processing 16/47 [  58s]
# wwwroot/ipynb/Fiji.ipynb
# Written file to Fiji.ipynb
# Processing 16/47 [  58s]
# wwwroot/ipynb/France.ipynb
# Written file to France.ipynbWritten file to wwwroot/html/Estonia.html
#
# Processing 16/47 [  58s]
# wwwroot/ipynb/Finland.ipynb
# Written file to Finland.ipynb
# Written file to wwwroot/html/Ethiopia.html
# Processing 16/47 [  58s]
# wwwroot/ipynb/Gabon.ipynb
# Written file to Gabon.ipynb
# Written file to wwwroot/html/Fiji.html
# Processing 17/47 [  62s]
# wwwroot/ipynb/Gambia.ipynb
# Written file to Gambia.ipynb
# Written file to wwwroot/html/France.html
# Written file to wwwroot/html/Finland.html
# Processing 17/47 [  62s]
# wwwroot/ipynb/Germany.ipynb
# Written file to Germany.ipynb
# Processing 17/47 [  62s]
# wwwroot/ipynb/Georgia.ipynb
# Written file to Georgia.ipynb
# Written file to wwwroot/html/Gabon.html
# Processing 17/47 [  62s]
# wwwroot/ipynb/Ghana.ipynb
# Written file to Ghana.ipynb
# Written file to wwwroot/html/Germany.html
# Processing 18/47 [  66s]
# wwwroot/ipynb/Guatemala.ipynb
# Written file to Guatemala.ipynb
# Written file to wwwroot/html/Gambia.html
# Processing 18/47 [  66s]
# wwwroot/ipynb/Greece.ipynb
# Written file to Greece.ipynb
# Written file to wwwroot/html/Ghana.html
# Processing 18/47 [  66s]
# wwwroot/ipynb/Guinea.ipynb
# Written file to Guinea.ipynb
# Written file to wwwroot/html/Georgia.html
# Processing 18/47 [  66s]
# wwwroot/ipynb/Grenada.ipynb
# Written file to Grenada.ipynb
# Written file to wwwroot/html/Guatemala.html
# Processing 19/47 [  70s]
# wwwroot/ipynb/Haiti.ipynb
# Written file to Haiti.ipynb
# Written file to wwwroot/html/Guinea.html
# Written file to wwwroot/html/Greece.html
# Processing 19/47 [  70s]Processing 19/47 [  70s]
#
# wwwroot/ipynb/Guinea-Bissau.ipynbwwwroot/ipynb/Holy-See.ipynb
#
# Written file to Holy-See.ipynbWritten file to Guinea-Bissau.ipynb
#
# Written file to wwwroot/html/Grenada.html
# Processing 19/47 [  70s]
# wwwroot/ipynb/Guyana.ipynb
# Written file to Guyana.ipynb
# Written file to wwwroot/html/Holy-See.html
# Written file to wwwroot/html/Haiti.html
# Processing 20/47 [  74s]
# wwwroot/ipynb/Iceland.ipynb
# Written file to Iceland.ipynbProcessing 20/47 [  74s]
#
# wwwroot/ipynb/India.ipynb
# Written file to India.ipynb
# Written file to wwwroot/html/Guinea-Bissau.html
# Processing 20/47 [  74s]
# wwwroot/ipynb/Honduras.ipynb
# Written file to Honduras.ipynb
# Written file to wwwroot/html/Guyana.html
# Processing 20/47 [  74s]
# wwwroot/ipynb/Hungary.ipynb
# Written file to Hungary.ipynb
# Written file to wwwroot/html/India.html
# Processing 21/47 [  77s]
# wwwroot/ipynb/Ireland.ipynb
# Written file to Ireland.ipynb
# Written file to wwwroot/html/Honduras.html
# Processing 21/47 [  78s]
# wwwroot/ipynb/Indonesia.ipynb
# Written file to Indonesia.ipynb
# Written file to wwwroot/html/Iceland.html
# Processing 21/47 [  78s]
# wwwroot/ipynb/Iraq.ipynb
# Written file to Iraq.ipynb
# Written file to wwwroot/html/Hungary.html
# Processing 21/47 [  78s]
# wwwroot/ipynb/Iran.ipynb
# Written file to Iran.ipynb
# Written file to wwwroot/html/Ireland.html
# Processing 22/47 [  81s]
# wwwroot/ipynb/Japan.ipynb
# Written file to Japan.ipynb
# Written file to wwwroot/html/Iraq.html
# Processing 22/47 [  81s]
# wwwroot/ipynb/Jamaica.ipynb
# Written file to Jamaica.ipynb
# Written file to wwwroot/html/Indonesia.html
# Processing 22/47 [  81s]
# wwwroot/ipynb/Israel.ipynb
# Written file to Israel.ipynb
# Written file to wwwroot/html/Iran.html
# Processing 22/47 [  81s]
# wwwroot/ipynb/Italy.ipynb
# Written file to Italy.ipynb
# Written file to wwwroot/html/Israel.html
# Processing 23/47 [  85s]
# wwwroot/ipynb/Jordan.ipynb
# Written file to Jordan.ipynb
# Written file to wwwroot/html/Japan.html
# Written file to wwwroot/html/Jamaica.html
# Processing 23/47 [  85s]
# wwwroot/ipynb/Korea--South.ipynb
# Written file to Korea--South.ipynb
# Processing 23/47 [  85s]
# wwwroot/ipynb/Kenya.ipynb
# Written file to Kenya.ipynb
# Written file to wwwroot/html/Italy.html
# Processing 23/47 [  85s]
# wwwroot/ipynb/Kazakhstan.ipynb
# Written file to Kazakhstan.ipynb
# Written file to wwwroot/html/Korea--South.html
# Processing 24/47 [  89s]
# wwwroot/ipynb/Laos.ipynb
# Written file to Laos.ipynb
# Written file to wwwroot/html/Jordan.html
# Processing 24/47 [  89s]
# wwwroot/ipynb/Kosovo.ipynb
# Written file to Kosovo.ipynb
# Written file to wwwroot/html/Kenya.html
# Written file to wwwroot/html/Kazakhstan.html
# Processing 24/47 [  89s]
# wwwroot/ipynb/Kyrgyzstan.ipynb
# Written file to Kyrgyzstan.ipynb
# Processing 24/47 [  89s]
# wwwroot/ipynb/Kuwait.ipynb
# Written file to Kuwait.ipynb
# Written file to wwwroot/html/Kuwait.html
# Processing 25/47 [  93s]
# wwwroot/ipynb/Lebanon.ipynb
# Written file to Lebanon.ipynb
# Written file to wwwroot/html/Kosovo.html
# Written file to wwwroot/html/Laos.html
# Processing 25/47 [  93s]
# wwwroot/ipynb/Latvia.ipynb
# Written file to Latvia.ipynb
# Processing 25/47 [  93s]
# wwwroot/ipynb/Liberia.ipynb
# Written file to Liberia.ipynb
# Written file to wwwroot/html/Kyrgyzstan.html
# Processing 25/47 [  93s]
# wwwroot/ipynb/Lesotho.ipynb
# Written file to Lesotho.ipynb
# Written file to wwwroot/html/Lebanon.html
# Written file to wwwroot/html/Liberia.html
# Processing 26/47 [  97s]
# wwwroot/ipynb/Liechtenstein.ipynb
# Written file to Liechtenstein.ipynbProcessing 26/47 [  97s]
#
# wwwroot/ipynb/Luxembourg.ipynb
# Written file to Luxembourg.ipynb
# Written file to wwwroot/html/Latvia.html
# Processing 26/47 [  97s]
# wwwroot/ipynb/Libya.ipynb
# Written file to Libya.ipynb
# Written file to wwwroot/html/Lesotho.html
# Processing 26/47 [  97s]
# wwwroot/ipynb/Lithuania.ipynb
# Written file to Lithuania.ipynb
# Written file to wwwroot/html/Liechtenstein.html
# Processing 27/47 [ 101s]
# wwwroot/ipynb/Madagascar.ipynb
# Written file to Madagascar.ipynb
# Written file to wwwroot/html/Luxembourg.html
# Processing 27/47 [ 101s]
# wwwroot/ipynb/Malaysia.ipynb
# Written file to Malaysia.ipynb
# Written file to wwwroot/html/Libya.html
# Processing 27/47 [ 101s]
# wwwroot/ipynb/MS-Zaandam.ipynb
# Written file to MS-Zaandam.ipynb
# Written file to wwwroot/html/Lithuania.html
# Processing 27/47 [ 101s]
# wwwroot/ipynb/Malawi.ipynb
# Written file to Malawi.ipynb
# Written file to wwwroot/html/Malaysia.html
# Written file to wwwroot/html/Madagascar.htmlProcessing 28/47 [ 105s]
#
# wwwroot/ipynb/Mauritania.ipynb
# Written file to Mauritania.ipynb
# Processing 28/47 [ 105s]
# wwwroot/ipynb/Mali.ipynb
# Written file to Mali.ipynb
# Written file to wwwroot/html/MS-Zaandam.html
# Processing 28/47 [ 105s]
# wwwroot/ipynb/Maldives.ipynb
# Written file to Maldives.ipynb
# Written file to wwwroot/html/Malawi.html
# Processing 28/47 [ 105s]
# wwwroot/ipynb/Malta.ipynb
# Written file to Malta.ipynb
# Written file to wwwroot/html/Mauritania.html
# Written file to wwwroot/html/Mali.html
# Processing 29/47 [ 109s]
# wwwroot/ipynb/Monaco.ipynb
# Written file to Monaco.ipynb
# Processing 29/47 [ 109s]
# wwwroot/ipynb/Mexico.ipynb
# Written file to Mexico.ipynb
# Written file to wwwroot/html/Maldives.html
# Written file to wwwroot/html/Malta.html
# Processing 29/47 [ 109s]
# wwwroot/ipynb/Mauritius.ipynb
# Written file to Mauritius.ipynb
# Processing 29/47 [ 109s]
# wwwroot/ipynb/Moldova.ipynb
# Written file to Moldova.ipynb
# Written file to wwwroot/html/Mexico.html
# Processing 30/47 [ 113s]
# wwwroot/ipynb/Montenegro.ipynb
# Written file to Montenegro.ipynb
# Written file to wwwroot/html/Monaco.html
# Written file to wwwroot/html/Moldova.html
# Processing 30/47 [ 113s]
# wwwroot/ipynb/Mozambique.ipynb
# Written file to Mozambique.ipynb
# Processing 30/47 [ 113s]
# wwwroot/ipynb/Morocco.ipynb
# Written file to Morocco.ipynb
# Written file to wwwroot/html/Mauritius.html
# Processing 30/47 [ 113s]
# wwwroot/ipynb/Mongolia.ipynb
# Written file to Mongolia.ipynb
# Written file to wwwroot/html/Montenegro.html
# Written file to wwwroot/html/Morocco.html
# Processing 31/47 [ 117s]
# Written file to wwwroot/html/Mozambique.html
# wwwroot/ipynb/Nepal.ipynb
# Written file to Nepal.ipynb
# Processing 31/47 [ 117s]
# wwwroot/ipynb/New-Zealand.ipynb
# Written file to New-Zealand.ipynb
# Processing 31/47 [ 117s]
# wwwroot/ipynb/Netherlands.ipynb
# Written file to Netherlands.ipynb
# Written file to wwwroot/html/Mongolia.html
# Processing 31/47 [ 117s]
# wwwroot/ipynb/Namibia.ipynb
# Written file to Namibia.ipynb
# Written file to wwwroot/html/Namibia.html
# Processing 32/47 [ 120s]
# wwwroot/ipynb/Nicaragua.ipynb
# Written file to Nicaragua.ipynb
# Written file to wwwroot/html/Netherlands.html
# Written file to wwwroot/html/Nepal.html
# Processing 32/47 [ 120s]
# wwwroot/ipynb/Nigeria.ipynb
# Written file to Nigeria.ipynb
# Processing 32/47 [ 120s]
# wwwroot/ipynb/Niger.ipynb
# Written file to Niger.ipynb
# Written file to wwwroot/html/New-Zealand.html
# Processing 32/47 [ 121s]
# wwwroot/ipynb/North-Macedonia.ipynb
# Written file to North-Macedonia.ipynb
# Written file to wwwroot/html/Nigeria.html
# Processing 33/47 [ 124s]
# wwwroot/ipynb/Pakistan.ipynb
# Written file to Pakistan.ipynb
# Written file to wwwroot/html/Niger.html
# Processing 33/47 [ 124s]
# wwwroot/ipynb/Oman.ipynb
# Written file to Oman.ipynb
# Written file to wwwroot/html/Nicaragua.html
# Processing 33/47 [ 124s]
# wwwroot/ipynb/Norway.ipynb
# Written file to Norway.ipynb
# Written file to wwwroot/html/North-Macedonia.html
# Processing 33/47 [ 125s]
# wwwroot/ipynb/Panama.ipynb
# Written file to Panama.ipynb
# Written file to wwwroot/html/Pakistan.html
# Processing 34/47 [ 128s]
# wwwroot/ipynb/Peru.ipynb
# Written file to Peru.ipynb
# Written file to wwwroot/html/Norway.html
# Written file to wwwroot/html/Oman.html
# Processing 34/47 [ 128s]
# wwwroot/ipynb/Papua-New-Guinea.ipynb
# Written file to Papua-New-Guinea.ipynb
# Processing 34/47 [ 128s]
# wwwroot/ipynb/Paraguay.ipynb
# Written file to Paraguay.ipynb
# Written file to wwwroot/html/Panama.html
# Processing 34/47 [ 128s]
# wwwroot/ipynb/Philippines.ipynb
# Written file to Philippines.ipynb
# Written file to wwwroot/html/Peru.html
# Processing 35/47 [ 132s]
# wwwroot/ipynb/Qatar.ipynb
# Written file to Qatar.ipynb
# Written file to wwwroot/html/Paraguay.html
# Processing 35/47 [ 132s]
# wwwroot/ipynb/Portugal.ipynb
# Written file to Portugal.ipynb
# Written file to wwwroot/html/Philippines.html
# Processing 35/47 [ 132s]
# wwwroot/ipynb/Romania.ipynb
# Written file to Romania.ipynb
# Written file to wwwroot/html/Papua-New-Guinea.html
# Processing 35/47 [ 132s]
# wwwroot/ipynb/Poland.ipynb
# Written file to Poland.ipynb
# Written file to wwwroot/html/Qatar.html
# Processing 36/47 [ 136s]
# wwwroot/ipynb/Saint-Kitts-and-Nevis.ipynb
# Written file to Saint-Kitts-and-Nevis.ipynb
# Written file to wwwroot/html/Romania.html
# Written file to wwwroot/html/Portugal.html
# Processing 36/47 [ 136s]
# wwwroot/ipynb/Saint-Lucia.ipynb
# Written file to Saint-Lucia.ipynb
# Processing 36/47 [ 136s]
# wwwroot/ipynb/Rwanda.ipynb
# Written file to Rwanda.ipynb
# Written file to wwwroot/html/Poland.html
# Processing 36/47 [ 136s]
# wwwroot/ipynb/Russia.ipynb
# Written file to Russia.ipynb
# Written file to wwwroot/html/Russia.html
# Processing 37/47 [ 140s]
# wwwroot/ipynb/Saint-Vincent-and-the-Grenadines.ipynb
# Written file to Saint-Vincent-and-the-Grenadines.ipynb
# Written file to wwwroot/html/Saint-Lucia.html
# Processing 37/47 [ 140s]
# wwwroot/ipynb/Saudi-Arabia.ipynb
# Written file to Saudi-Arabia.ipynb
# Written file to wwwroot/html/Rwanda.htmlWritten file to wwwroot/html/Saint-Kitts-and-Nevis.html
#
# Processing 37/47 [ 140s]Processing 37/47 [ 140s]
#
# wwwroot/ipynb/Sao-Tome-and-Principe.ipynb
# wwwroot/ipynb/San-Marino.ipynbWritten file to Sao-Tome-and-Principe.ipynb
#
# Written file to San-Marino.ipynb
# Written file to wwwroot/html/Saudi-Arabia.html
# Processing 38/47 [ 143s]
# wwwroot/ipynb/Sierra-Leone.ipynb
# Written file to Sierra-Leone.ipynb
# Written file to wwwroot/html/Saint-Vincent-and-the-Grenadines.html
# Processing 38/47 [ 144s]
# wwwroot/ipynb/Senegal.ipynb
# Written file to Senegal.ipynb
# Written file to wwwroot/html/Sao-Tome-and-Principe.html
# Processing 38/47 [ 144s]
# wwwroot/ipynb/Seychelles.ipynb
# Written file to Seychelles.ipynb
# Written file to wwwroot/html/San-Marino.html
# Processing 38/47 [ 144s]
# wwwroot/ipynb/Serbia.ipynb
# Written file to Serbia.ipynb
# Written file to wwwroot/html/Sierra-Leone.html
# Processing 39/47 [ 148s]
# wwwroot/ipynb/Somalia.ipynb
# Written file to Somalia.ipynb
# Written file to wwwroot/html/Senegal.html
# Processing 39/47 [ 148s]
# wwwroot/ipynb/Singapore.ipynb
# Written file to Singapore.ipynb
# Written file to wwwroot/html/Serbia.html
# Processing 39/47 [ 148s]
# wwwroot/ipynb/Slovakia.ipynb
# Written file to Slovakia.ipynb
# Written file to wwwroot/html/Seychelles.html
# Processing 39/47 [ 148s]
# wwwroot/ipynb/Slovenia.ipynb
# Written file to Slovenia.ipynb
# Written file to wwwroot/html/Singapore.html
# Written file to wwwroot/html/Somalia.html
# Processing 40/47 [ 152s]
# wwwroot/ipynb/South-Africa.ipynb
# Written file to South-Africa.ipynb
# Processing 40/47 [ 152s]
# wwwroot/ipynb/Sri-Lanka.ipynb
# Written file to Sri-Lanka.ipynb
# Written file to wwwroot/html/Slovakia.html
# Processing 40/47 [ 152s]
# wwwroot/ipynb/South-Sudan.ipynb
# Written file to South-Sudan.ipynb
# Written file to wwwroot/html/Slovenia.html
# Processing 40/47 [ 152s]
# wwwroot/ipynb/Spain.ipynb
# Written file to Spain.ipynb
# Written file to wwwroot/html/South-Africa.html
# Processing 41/47 [ 156s]
# wwwroot/ipynb/Sudan.ipynb
# Written file to Sudan.ipynb
# Written file to wwwroot/html/Sri-Lanka.html
# Processing 41/47 [ 156s]
# wwwroot/ipynb/Switzerland.ipynb
# Written file to Switzerland.ipynb
# Written file to wwwroot/html/Spain.html
# Processing 41/47 [ 156s]
# wwwroot/ipynb/Sweden.ipynb
# Written file to Sweden.ipynb
# Written file to wwwroot/html/South-Sudan.html
# Processing 41/47 [ 156s]
# wwwroot/ipynb/Suriname.ipynb
# Written file to Suriname.ipynb
# Written file to wwwroot/html/Sudan.html
# Processing 42/47 [ 159s]
# wwwroot/ipynb/Syria.ipynb
# Written file to Syria.ipynb
# Written file to wwwroot/html/Switzerland.html
# Processing 42/47 [ 160s]
# wwwroot/ipynb/Tanzania.ipynb
# Written file to Tanzania.ipynb
# Written file to wwwroot/html/Sweden.html
# Processing 42/47 [ 160s]
# wwwroot/ipynb/Tajikistan.ipynb
# Written file to Tajikistan.ipynb
# Written file to wwwroot/html/Suriname.html
# Processing 42/47 [ 160s]
# wwwroot/ipynb/Taiwan*.ipynb
# Written file to Taiwan*.ipynb
# Written file to wwwroot/html/Syria.html
# Processing 43/47 [ 163s]
# wwwroot/ipynb/Thailand.ipynb
# Written file to Thailand.ipynb
# Written file to wwwroot/html/Taiwan*.html
# Processing 43/47 [ 164s]
# wwwroot/ipynb/Timor-Leste.ipynb
# Written file to Timor-Leste.ipynb
# Written file to wwwroot/html/Tanzania.html
# Processing 43/47 [ 164s]
# wwwroot/ipynb/Trinidad-and-Tobago.ipynb
# Written file to Trinidad-and-Tobago.ipynb
# Written file to wwwroot/html/Tajikistan.html
# Processing 43/47 [ 164s]
# wwwroot/ipynb/Togo.ipynb
# Written file to Togo.ipynb
# Written file to wwwroot/html/Thailand.html
# Processing 44/47 [ 167s]
# wwwroot/ipynb/Tunisia.ipynb
# Written file to Tunisia.ipynb
# Written file to wwwroot/html/Timor-Leste.html
# Processing 44/47 [ 167s]
# wwwroot/ipynb/Turkey.ipynb
# Written file to Turkey.ipynb
# Written file to wwwroot/html/Togo.html
# Processing 44/47 [ 168s]
# wwwroot/ipynb/US.ipynb
# Written file to US.ipynb
# Written file to wwwroot/html/Trinidad-and-Tobago.html
# Processing 44/47 [ 168s]
# wwwroot/ipynb/Uganda.ipynb
# Written file to Uganda.ipynb
# Written file to wwwroot/html/Turkey.html
# Processing 45/47 [ 171s]Written file to wwwroot/html/Tunisia.html
#
# wwwroot/ipynb/United-Arab-Emirates.ipynb
# Written file to United-Arab-Emirates.ipynb
# Processing 45/47 [ 171s]
# wwwroot/ipynb/Ukraine.ipynb
# Written file to Ukraine.ipynbWritten file to wwwroot/html/US.html
#
# Processing 45/47 [ 171s]
# wwwroot/ipynb/United-Kingdom.ipynb
# Written file to United-Kingdom.ipynb
# Written file to wwwroot/html/Uganda.html
# Processing 45/47 [ 172s]
# wwwroot/ipynb/Uruguay.ipynb
# Written file to Uruguay.ipynb
# Written file to wwwroot/html/Ukraine.html
# Processing 46/47 [ 175s]
# wwwroot/ipynb/Uzbekistan.ipynb
# Written file to Uzbekistan.ipynb
# Written file to wwwroot/html/United-Kingdom.html
# Written file to wwwroot/html/United-Arab-Emirates.html
# Processing 46/47 [ 175s]
# wwwroot/ipynb/Vietnam.ipynb
# Written file to Vietnam.ipynbProcessing 46/47 [ 175s]
#
# wwwroot/ipynb/Venezuela.ipynb
# Written file to Venezuela.ipynb
# Written file to wwwroot/html/Uruguay.html
# Processing 46/47 [ 176s]
# wwwroot/ipynb/West-Bank-and-Gaza.ipynb
# Written file to West-Bank-and-Gaza.ipynb
# Written file to wwwroot/html/Uzbekistan.html
# Processing 47/47 [ 179s]
# wwwroot/ipynb/Western-Sahara.ipynb
# Written file to Western-Sahara.ipynb
# Written file to wwwroot/html/Vietnam.html
# Processing 47/47 [ 179s]
# wwwroot/ipynb/Zambia.ipynb
# Written file to Zambia.ipynb
# Written file to wwwroot/html/Venezuela.html
# Processing 47/47 [ 179s]
# wwwroot/ipynb/Yemen.ipynb
# Written file to Yemen.ipynb
# Written file to wwwroot/html/West-Bank-and-Gaza.html
# Processing 47/47 [ 180s]
# wwwroot/ipynb/Zimbabwe.ipynb
# Written file to Zimbabwe.ipynb
# Written file to wwwroot/html/Yemen.html
# Created 47 (skipped 0) notebooks and html versions in 183.32865524291992 seconds
# Written file to wwwroot/html/Zambia.html
# Created 47 (skipped 0) notebooks and html versions in 183.40791392326355 seconds
# Written file to wwwroot/html/Western-Sahara.html
# Created 47 (skipped 0) notebooks and html versions in 183.41385769844055 seconds
# Written file to wwwroot/html/Zimbabwe.html
# Created 47 (skipped 0) notebooks and html versions in 183.8631055355072 seconds

# %%
index_md = create_markdown_index_list("world")

create_markdown_index_page(
    index_md, title=TITLE_PREFIX + " Countries of the world", 
    pelican_file_path="pelican/content/countries.md", save_as="countries", 
    wwwroot=wwwroot
)

# %% [markdown]
# ## Germany Report Generation

# %%
def get_germany_regions_list():
    data_germany = fetch_data_germany()
    land_kreis = data_germany[['Bundesland', 'Landkreis']]
    ordered = land_kreis.sort_values(['Bundesland', 'Landkreis'])
    return ordered.drop_duplicates().values.tolist()

# %%
germany_regions = get_germany_regions_list()
wwwroot = "wwwroot"

# data cleaning: on 13 April, we had a Landkreis "LK Göttingen (alt)"
# with only one data point. This causes plots to fail, because there
# is nothing to plot, and then the legend() command failed.
# We assume that the RKI labels unusual data with '(alt)', and remove those.

alt_data_sets = ["(alt)" in r[1].lower() for r in germany_regions]
alt_data_sets[20] = True
if sum(alt_data_sets) > 0:
    bad_datasests = list(compress(germany_regions, alt_data_sets))
    
    print(f"Removing datasets label with '(alt)': {bad_datasests}")

    for bd in bad_datasests:
        c, d, _ = germany_get_region(landkreis=bd[1])
        print(f"\tremoved: {bd} : len(cases)={len(c)}, len(deaths)={len(d)}")

    bad_indecies = list(compress(range(len(alt_data_sets)), alt_data_sets))

    [germany_regions.pop(i) for i in bad_indecies]
# Out:
# Removing datasets label with '(alt)': [['Baden-Württemberg', 'LK Ortenaukreis']]
# 	removed: ['Baden-Württemberg', 'LK Ortenaukreis'] : len(cases)=83, len(deaths)=83

# %%
if debug:
    germany_regions = germany_regions[0:8]
    cores=4

# %%
create_html_reports(
    Reporter=Germany, regions=germany_regions,
    wwwroot=wwwroot, cores=cores, force=True
)
# Out:
# Using 4 processes with tasks:
# 	0: [['Baden-Württemberg', 'LK Alb-Donau-Kreis'], ['Baden-Württemberg', 'LK Böblingen']]
# 	1: [['Baden-Württemberg', 'LK Biberach'], ['Baden-Württemberg', 'LK Calw']]
# 	2: [['Baden-Württemberg', 'LK Bodenseekreis'], ['Baden-Württemberg', 'LK Emmendingen']]
# 	3: [['Baden-Württemberg', 'LK Breisgau-Hochschwarzwald'], ['Baden-Württemberg', 'LK Enzkreis']]
#
# Processing 1/2 [   0s]
# wwwroot/ipynb/Germany-Baden-Württemberg-LK-Breisgau-Hochschwarzwald.ipynb
# Processing 1/2 [   0s]Written file to Germany-Baden-Württemberg-LK-Breisgau-Hochschwarzwald.ipynb
#
# wwwroot/ipynb/Germany-Baden-Württemberg-LK-Biberach.ipynbProcessing 1/2 [   0s]
#
# Written file to Germany-Baden-Württemberg-LK-Biberach.ipynb
# wwwroot/ipynb/Germany-Baden-Württemberg-LK-Bodenseekreis.ipynb
# Written file to Germany-Baden-Württemberg-LK-Bodenseekreis.ipynb
# Processing 1/2 [   0s]
# wwwroot/ipynb/Germany-Baden-Württemberg-LK-Alb-Donau-Kreis.ipynb
# Written file to Germany-Baden-Württemberg-LK-Alb-Donau-Kreis.ipynb
# Written file to wwwroot/html/Germany-Baden-Württemberg-LK-Bodenseekreis.html
# Written file to wwwroot/html/Germany-Baden-Württemberg-LK-Biberach.html
# Written file to wwwroot/html/Germany-Baden-Württemberg-LK-Alb-Donau-Kreis.html
# Written file to wwwroot/html/Germany-Baden-Württemberg-LK-Breisgau-Hochschwarzwald.html
# Processing 2/2 [   5s]
# wwwroot/ipynb/Germany-Baden-Württemberg-LK-Emmendingen.ipynb
# Written file to Germany-Baden-Württemberg-LK-Emmendingen.ipynb
# Processing 2/2 [   5s]
# wwwroot/ipynb/Germany-Baden-Württemberg-LK-Calw.ipynb
# Written file to Germany-Baden-Württemberg-LK-Calw.ipynb
# Processing 2/2 [   5s]
# wwwroot/ipynb/Germany-Baden-Württemberg-LK-Böblingen.ipynb
# Written file to Germany-Baden-Württemberg-LK-Böblingen.ipynb
# Processing 2/2 [   5s]
# wwwroot/ipynb/Germany-Baden-Württemberg-LK-Enzkreis.ipynb
# Written file to Germany-Baden-Württemberg-LK-Enzkreis.ipynb
# Written file to wwwroot/html/Germany-Baden-Württemberg-LK-Calw.html
# Created 2 (skipped 0) notebooks and html versions in 9.905300617218018 seconds
# Written file to wwwroot/html/Germany-Baden-Württemberg-LK-Emmendingen.html
# Created 2 (skipped 0) notebooks and html versions in 9.941703796386719 seconds
# Written file to wwwroot/html/Germany-Baden-Württemberg-LK-Böblingen.html
# Created 2 (skipped 0) notebooks and html versions in 10.11304259300232 seconds
# Written file to wwwroot/html/Germany-Baden-Württemberg-LK-Enzkreis.html
# Created 2 (skipped 0) notebooks and html versions in 10.123231410980225 seconds

# %%
index_md = create_markdown_index_list(category="Germany")

create_markdown_index_page(
    index_md, title= TITLE_PREFIX + " Germany", 
    pelican_file_path="pelican/content/germany.md", save_as="germany", 
    wwwroot=wwwroot
)

# %% [markdown]
# ## USA Report Generation

# %%
states = get_US_region_list()

# %%
states = states[0:8]
cores=4

# %%
create_html_reports(
    Reporter=USA, regions=states,
    wwwroot=wwwroot, cores=cores, force=True
)
# Out:
# Using 4 processes with tasks:
# 	0: ['Alabama', 'Arkansas']
# 	1: ['Alaska', 'California']
# 	2: ['American Samoa', 'Colorado']
# 	3: ['Arizona', 'Connecticut']
#
# Processing 1/2 [   0s]Processing 1/2 [   0s]
#
# wwwroot/ipynb/US-American-Samoa.ipynb
# wwwroot/ipynb/US-Arizona.ipynbProcessing 1/2 [   0s]Written file to US-American-Samoa.ipynb
#
#
# Written file to US-Arizona.ipynbwwwroot/ipynb/US-Alabama.ipynb
#
# Processing 1/2 [   0s]Written file to US-Alabama.ipynb
#
# wwwroot/ipynb/US-Alaska.ipynb
# Written file to US-Alaska.ipynb
# Written file to wwwroot/html/US-Alaska.html
# Written file to wwwroot/html/US-Arizona.html
# Processing 2/2 [   2s]
# wwwroot/ipynb/US-California.ipynb
# Processing 2/2 [   2s]
# Written file to US-California.ipynbwwwroot/ipynb/US-Connecticut.ipynb
#
# Written file to US-Connecticut.ipynb
# Written file to wwwroot/html/US-American-Samoa.html
# Processing 2/2 [   2s]
# wwwroot/ipynb/US-Colorado.ipynb
# Written file to US-Colorado.ipynb
# Written file to wwwroot/html/US-Alabama.html
# Processing 2/2 [   2s]
# wwwroot/ipynb/US-Arkansas.ipynb
# Written file to US-Arkansas.ipynb
# Written file to wwwroot/html/US-California.html
# Created 2 (skipped 0) notebooks and html versions in 3.1213958263397217 seconds
# Written file to wwwroot/html/US-Colorado.html
# Created 2 (skipped 0) notebooks and html versions in 3.15360951423645 seconds
# Written file to wwwroot/html/US-Connecticut.html
# Created 2 (skipped 0) notebooks and html versions in 3.169668674468994 seconds
# Written file to wwwroot/html/US-Arkansas.html
# Created 2 (skipped 0) notebooks and html versions in 3.264503002166748 seconds

# %%
index_md = create_markdown_index_list("US")

create_markdown_index_page(
    index_md, title=TITLE_PREFIX + " United States", 
    pelican_file_path="pelican/content/US.md", save_as="us", 
    wwwroot=wwwroot
)

# %% [markdown]
# ### HTML Pages for All Regions

# %%
index_md = create_markdown_index_list("all-regions")
create_markdown_index_page(
    index_md, title=TITLE_PREFIX + " All regions and countries", 
    pelican_file_path="pelican/content/all-regions.md", save_as="all-regions", 
    wwwroot=wwwroot
)

# %% [markdown]
# ## Error Reporting

# %%
ms = MetadataRegion.get_all()
for name in ms:
    m = MetadataRegion(name)
    dt = m.last_updated_hours_ago()
    if dt > 2:
        print(f"Problem with '{name}', last update: {dt} ago ")
