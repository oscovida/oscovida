# %% [markdown]
# # Hungary: Zala
#
# * Homepage of project: https://oscovida.github.io
# * [Execute this Jupyter Notebook using myBinder](https://mybinder.org/v2/gh/oscovida/binder/master?filepath=ipynb/Hungary-Zala.ipynb)
# * notebook creation time: 24/06/2020 13:11:24

# %%
import sys
sys.path.append('../..')
# %config InlineBackend.figure_formats = ['svg']
from oscovida import *
from oscovida.hungary_data import get_region_hungary, fetch_data_hungary_last_execution
region = "Zala"

# %%
overview(country="Hungary", region="Zala");
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
# load the data 
cases, _, region_label = get_region_hungary(county="Zala")

# compose into one table
table = compose_dataframe_summary(cases, None)

# show tables with up to 500 rows
pd.set_option("max_rows", 500)  

# display the table
table
# Out:
#             total cases  daily new cases
# Dátum
# 2020-06-22          260                0
# 2020-06-21          260                0
# 2020-06-20          260               -1
# 2020-06-19          261                0
# 2020-06-18          261                0
# 2020-06-17          261                0
# 2020-06-15          261                0
# 2020-06-14          261                0
# 2020-06-13          261                1
# 2020-06-12          260                0
# 2020-06-11          260                1
# 2020-06-10          259                0
# 2020-06-09          259                0
# 2020-06-08          259                0
# 2020-06-07          259                1
# 2020-06-06          258                1
# 2020-06-05          257                1
# 2020-06-04          256                1
# 2020-06-03          255                0
# 2020-06-02          255                0
# 2020-06-01          255                2
# 2020-05-31          253                1
# ...

# %% [markdown]
# # Explore the data in your web browser
#
# - If you want to execute this notebook, [click here to use myBinder](https://mybinder.org/v2/gh/oscovida/binder/master?filepath=ipynb/Hungary-Zala.ipynb)
# - and wait (~1 to 2 minutes)
# - Then press SHIFT+RETURN to advance code cell to code cell
# - See http://jupyter.org for more details on how to use Jupyter Notebook

# %% [markdown]
# # Acknowledgements:
#
# - Johns Hopkins University provides data for countries
# - Robert Koch Institute provides data for within Germany
# - Open source and scientific computing community for the data tools
# - Github for hosting repository and html files
# - Project Jupyter for the Notebook and binder service
# - The H2020 project Photon and Neutron Open Science Cloud ([PaNOSC](https://www.panosc.eu/))
#
# --------------------
#
# - notebook creation time: 24/06/2020 13:11:24

# %%
print(f"Download of data from Robert Koch Institute at {fetch_data_hungary_last_execution()}.")
# Out:
# Download of data from Robert Koch Institute at 24/06/2020 13:12:22.

# %%
# to force a fresh download of data, run "clear_cache()"
