# %%
import sys
sys.path.append('..')
import oscovida

# %%
data = oscovida.germany_get_region(state='Baden-Württemberg')

# %%
type(data)
# Out:
# tuple

# %%
type(data[0])
# Out:
# pandas.core.series.Series

# %%
type(data[1])
# Out:
# pandas.core.series.Series

# %%
data[2]
# Out:
# 'Germany-Baden-Württemberg'

# %%
x = oscovida.overview(country='Germany', subregion='LK Ahrweiler')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
import sys
sys.path.append('..')
import oscovida
x = oscovida.overview(country='Hungary', region='Budapest')
