# %%
# %config InlineBackend.figure_formats = ['svg']
import oscovida

# %%
print(f"oscovida version {oscovida.__version__}")
# Out:
# oscovida version 0.2.5

# %%
import nbconvert
print(f"nbconvert version {nbconvert.__version__}")
# Out:
# nbconvert version 5.6.1

# %%
oscovida.overview("Germany");
